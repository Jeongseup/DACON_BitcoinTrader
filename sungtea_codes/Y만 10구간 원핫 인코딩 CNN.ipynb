# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Reshape, Conv1D, MaxPooling1D, Flatten
import matplotlib.pyplot as plt
from sklearn.preprocessing import KBinsDiscretizer
import pandas as pd
# %matplotlib inline

# %%
#데이터 불러오기(경로)
train_x_df = pd.read_csv('/content/drive/MyDrive/capstone2021/train_x_df.csv')
train_y_df = pd.read_csv('/content/drive/MyDrive/capstone2021/train_y_df.csv')
test_x_df = pd.read_csv('/content/drive/MyDrive/capstone2021/test_x_df.csv')
sample_submission=pd.read_csv('/content/drive/MyDrive/capstone2021/sample_submission.csv')
train_x_df = train_x_df.astype('float')
train_y_df = train_y_df.astype('float')
test_x_df = test_x_df.astype('float')
sample_submission=sample_submission.astype('float')

# %%
# 3차원 array로 변경
def df2d_to_array3d(df_2d):

    feature_size = df_2d.iloc[:,2:].shape[1]
    time_size = len(df_2d.time.value_counts())
    sample_size = len(df_2d.sample_id.value_counts())
    array_3d = df_2d.iloc[:,2:].values.reshape([sample_size, time_size, feature_size])
    return array_3d

def kbindiscreter(input_array):
  kb = KBinsDiscretizer(n_bins=10, strategy='uniform', encode='ordinal')
  processed_data = np.zeros((input_array.shape[0], input_array.shape[1], 1))
  for i in range(input_array.shape[0]):
    # coin_index_export args : (input_array, coin_num)
    processing_array = input_array[i,:,1]
    #globals()['outliery_array{}'.format(i)] = train_y_array[outlier[i],:,1]
    kb.fit(processing_array.reshape(input_array.shape[1],1))
    processed_fit = kb.transform(processing_array.reshape(input_array.shape[1],1))
    #globals()['outliery_fit{}'.format(i)] = kb.transform(globals()['outliery_array{}'.format(i)].reshape(120,1))
    processed_data[i,:,:] = processed_fit
  return processed_data

# %%
train_x_array = df2d_to_array3d(train_x_df)
train_y_array = df2d_to_array3d(train_y_df)
test_x_array = df2d_to_array3d(test_x_df)

# %%
xarray = kbindiscreter(train_x_array)
yarray = kbindiscreter(train_y_array)

# %%
df2 = xarray[:100,:].reshape(100,1380,1)

# %%
X_train = []
y_train = []
n_future = 1 # Number of days we want to predict into the future.
n_past = 120 # Number of past days we want to use to predict future.
for idx in range(df2.shape[0]):
    for i in range(n_past, df2.shape[1] - n_future +1):
        X_train.append(df2[idx, i - n_past:i,:])
        y_train.append(df2[idx, i:i+n_future, ])
X_train, y_train = np.array(X_train), np.array(y_train)
print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (126000, 120, 1).
# y_train shape == (126000, 1, 1).

# %%
y_traina = np.zeros((y_train.shape[0],10))
for i in range(y_train.shape[0]):
  for j in range(10):
    if y_train[i] == j:
      y_traina[i,j] = 1

# %%
x_traina = X_train

# %%
model = Sequential()

model.add(Conv1D(64,10, activation='relu', input_shape=(x_traina.shape[1],x_traina.shape[2] )))
model.add(Conv1D(64,5, activation='relu'))
model.add(Conv1D(32,4, activation='relu'))
model.add(Conv1D(16,4, activation='relu'))
model.add(MaxPooling1D(4))


model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_traina,y_traina,epochs=50, validation_split=0.2,shuffle=True)
# Out:
# Epoch 1/50
# 3150/3150 [==============================] - 56s 4ms/step - loss: 1.1524 - accuracy: 0.5321 - val_loss: 0.6916 - val_accuracy: 0.7609
# Epoch 2/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.6946 - accuracy: 0.7423 - val_loss: 0.6971 - val_accuracy: 0.7540
# Epoch 3/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.6691 - accuracy: 0.7564 - val_loss: 0.6240 - val_accuracy: 0.7836
# Epoch 4/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.6394 - accuracy: 0.7704 - val_loss: 0.6039 - val_accuracy: 0.7945
# Epoch 5/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.6284 - accuracy: 0.7741 - val_loss: 0.6378 - val_accuracy: 0.7744
# Epoch 6/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.6125 - accuracy: 0.7816 - val_loss: 0.6368 - val_accuracy: 0.7806
# Epoch 7/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.6074 - accuracy: 0.7805 - val_loss: 0.6238 - val_accuracy: 0.7839
# Epoch 8/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.5872 - accuracy: 0.7894 - val_loss: 0.6410 - val_accuracy: 0.7743
# Epoch 9/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.5861 - accuracy: 0.7900 - val_loss: 0.6645 - val_accuracy: 0.7744
# Epoch 10/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.5744 - accuracy: 0.7929 - val_loss: 0.6526 - val_accuracy: 0.7777
# Epoch 11/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.5605 - accuracy: 0.7986 - val_loss: 0.6597 - val_accuracy: 0.7775
# Epoch 12/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.5508 - accuracy: 0.8012 - val_loss: 0.6766 - val_accuracy: 0.7792
# Epoch 13/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.5412 - accuracy: 0.8028 - val_loss: 0.7393 - val_accuracy: 0.7615
# Epoch 14/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.5281 - accuracy: 0.8070 - val_loss: 0.7140 - val_accuracy: 0.7650
# Epoch 15/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.5130 - accuracy: 0.8112 - val_loss: 0.7322 - val_accuracy: 0.7674
# Epoch 16/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.5042 - accuracy: 0.8151 - val_loss: 0.7630 - val_accuracy: 0.7635
# Epoch 17/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4913 - accuracy: 0.8196 - val_loss: 0.7642 - val_accuracy: 0.7665
# Epoch 18/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4773 - accuracy: 0.8228 - val_loss: 0.7564 - val_accuracy: 0.7617
# Epoch 19/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4746 - accuracy: 0.8255 - val_loss: 0.8123 - val_accuracy: 0.7584
# Epoch 20/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4575 - accuracy: 0.8297 - val_loss: 0.8198 - val_accuracy: 0.7574
# Epoch 21/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4539 - accuracy: 0.8321 - val_loss: 0.8592 - val_accuracy: 0.7554
# Epoch 22/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4387 - accuracy: 0.8366 - val_loss: 0.9206 - val_accuracy: 0.7428
# Epoch 23/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.4328 - accuracy: 0.8391 - val_loss: 0.8794 - val_accuracy: 0.7492
# Epoch 24/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4312 - accuracy: 0.8387 - val_loss: 0.8794 - val_accuracy: 0.7536
# Epoch 25/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4168 - accuracy: 0.8436 - val_loss: 0.9435 - val_accuracy: 0.7276
# Epoch 26/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.4116 - accuracy: 0.8454 - val_loss: 0.9095 - val_accuracy: 0.7524
# Epoch 27/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.4063 - accuracy: 0.8485 - val_loss: 1.0355 - val_accuracy: 0.7138
# Epoch 28/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.4020 - accuracy: 0.8499 - val_loss: 1.0207 - val_accuracy: 0.7425
# Epoch 29/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3938 - accuracy: 0.8518 - val_loss: 0.9819 - val_accuracy: 0.7460
# Epoch 30/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3836 - accuracy: 0.8548 - val_loss: 1.0465 - val_accuracy: 0.7365
# Epoch 31/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3788 - accuracy: 0.8571 - val_loss: 1.0573 - val_accuracy: 0.7429
# Epoch 32/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3732 - accuracy: 0.8586 - val_loss: 1.0451 - val_accuracy: 0.7375
# Epoch 33/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3654 - accuracy: 0.8630 - val_loss: 1.0369 - val_accuracy: 0.7413
# Epoch 34/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3599 - accuracy: 0.8616 - val_loss: 1.1123 - val_accuracy: 0.7367
# Epoch 35/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3555 - accuracy: 0.8658 - val_loss: 1.1432 - val_accuracy: 0.7354
# Epoch 36/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3503 - accuracy: 0.8665 - val_loss: 1.1202 - val_accuracy: 0.7366
# Epoch 37/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3498 - accuracy: 0.8678 - val_loss: 1.1677 - val_accuracy: 0.7329
# Epoch 38/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3463 - accuracy: 0.8683 - val_loss: 1.1885 - val_accuracy: 0.7288
# Epoch 39/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3415 - accuracy: 0.8704 - val_loss: 1.2172 - val_accuracy: 0.7160
# Epoch 40/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3366 - accuracy: 0.8728 - val_loss: 1.2298 - val_accuracy: 0.7202
# Epoch 41/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3311 - accuracy: 0.8738 - val_loss: 1.1999 - val_accuracy: 0.7218
# Epoch 42/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3371 - accuracy: 0.8721 - val_loss: 1.2213 - val_accuracy: 0.7367
# Epoch 43/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3265 - accuracy: 0.8758 - val_loss: 1.3129 - val_accuracy: 0.7281
# Epoch 44/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3243 - accuracy: 0.8767 - val_loss: 1.2765 - val_accuracy: 0.7254
# Epoch 45/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3222 - accuracy: 0.8778 - val_loss: 1.2762 - val_accuracy: 0.7326
# Epoch 46/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3219 - accuracy: 0.8789 - val_loss: 1.3299 - val_accuracy: 0.7276
# Epoch 47/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3148 - accuracy: 0.8802 - val_loss: 1.3933 - val_accuracy: 0.7275
# Epoch 48/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3131 - accuracy: 0.8812 - val_loss: 1.3286 - val_accuracy: 0.7244
# Epoch 49/50
# 3150/3150 [==============================] - 13s 4ms/step - loss: 0.3080 - accuracy: 0.8819 - val_loss: 1.3630 - val_accuracy: 0.7227
# Epoch 50/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 0.3155 - accuracy: 0.8795 - val_loss: 1.3492 - val_accuracy: 0.7273

# %%
# train 값 plotting

aa =x_traina[729:829,:,:] 
bb =y_traina[729:829,:]
predictions = model.predict(aa.reshape(100,120,1))

# %%
# prediction 값 원 핫 인코딩 -> '정수값
fa = []
for i in range(100):
  fc = model.predict(aa[i].reshape(1,120,1))
  fa.append(np.argmax(fc))

# %%
# real 값 원 핫 인코딩 -> '정수값
fb = []
for i in range(100):
  fb.append(np.argmax(bb[i]))

# %%
#plotting
plt.plot(fa, label="predictions")
plt.show()
plt.plot(fb, label="real")

# %%
#train set auto regression

aa =x_traina[800,:,:]
yhat=[]
x= aa.reshape(1,120,1)

# %%
for i in range(100):
  x=x.reshape(1,120,1)
  fc = model.predict(x)
  yhat.append(np.argmax(fc))
  fd = np.zeros((1,10))
  for j in range(10):
    if j==np.argmax(fc):
      fd[0,j] = 1
  
  x=x.reshape(120,1)
  x=np.vstack([x,np.argmax(fc)])
  x=x[1:,:]

# %%
bb = []
for x in range(100):
  bb.append(np.argmax(y_traina[800+x]))

# %%
# train set auto regression plotting
plt.plot(yhat,label="prediction")
plt.show()
plt.plot(bb, label="real")
plt.show()
plt.plot(yhat,label="prediction")
plt.plot(bb, label="real")

# %%
#val set auto regression
num= 100000
aa =x_traina[100000,:,:]
yhat=[]
x= aa.reshape(1,120,1)

# %%
for i in range(100):
  x=x.reshape(1,120,1)
  fc = model.predict(x)
  yhat.append(np.argmax(fc))
  fd = np.zeros((1,10))
  for j in range(10):
    if j==np.argmax(fc):
      fd[0,j] = 1
  
  x=x.reshape(120,1)
  x=np.vstack([x,np.argmax(fc)])
  x=x[1:,:]

# %%
bb = []
for x in range(100):
  bb.append(np.argmax(y_traina[num+x]))

# %%
plt.plot(yhat,label="prediction")
plt.show()
plt.plot(bb, label="real")
plt.show()
plt.plot(bb, label="real")
plt.plot(yhat,label="prediction")
