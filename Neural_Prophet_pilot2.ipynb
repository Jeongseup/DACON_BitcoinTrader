# %% [markdown]
# ## 데이콘 비트코인 가격 예측 - Neural Prophet pilot

# %% [markdown]
# ### library install & import, data load

# %%
# import library
from datetime import timedelta, datetime
from copy import deepcopy
import datetime
import argparse
import random
import warnings


import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid

from tqdm import tqdm
import matplotlib.pyplot as plt

# model
from neuralprophet import NeuralProphet
from neuralprophet import set_random_seed


# %matplotlib inline
warnings.filterwarnings(action = "ignore")

# read file
train_x_df = pd.read_csv("./data/train_x_df.csv")
train_y_df = pd.read_csv("./data/train_y_df.csv")
print("Reading Complete!")
# Out:
# Reading Complete!

# %% [markdown]
# ### data preprocess functions

# %%
def df2d_to_array3d(df_2d):

    ''' 입력 받은 2차원 데이터 프레임을 3차원 numpy array로 변경하는 함수 '''

    feature_size = df_2d.iloc[:,2:].shape[1]
    time_size = len(df_2d.time.value_counts())
    sample_size = len(df_2d.sample_id.value_counts())
    array_3d = df_2d.iloc[:,2:].values.reshape([sample_size, time_size, feature_size])
    
    return array_3d
    

def coin_index_export(input_array, coin_num):

    ''' 코인별 인덱스를 뽑아 list형식으로 만들어주는 함수 '''
    
    index = []
    sample_id_len = input_array.shape[0]
    coin_num_col = 0 

    for sample_id in range(sample_id_len):
        if input_array[sample_id, 0, coin_num_col] == coin_num:
            #print(sample_id)
            index.append(sample_id)
    
    return index


def prophet_preprocessor(x_series):
    
    # start time initialization
    start_time = '2021-01-01 00:00:00'
    start_dt = datetime.datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S')

    # datafram 만들기
    x_df = pd.DataFrame()
    # 분당 시간 데이터 시리즈 입력
    x_df['ds'] = [start_dt + datetime.timedelta(minutes = time_min) for time_min in np.arange(1, x_series.shape[0]+1).tolist()]
    # 가격 데이터 시리즈 입력
    x_df['y'] = x_series.tolist()

    return x_df

# %% [markdown]
# ### parameter setting

# %%
# params_grid = {'n_changepoints':[5, 10, 15, 20], #default 5
#                 'changepoints_range' : [0.9, 0.95, 1.0], #defalut 0.8
#                 'num_hidden_layers' : [1, 2],
#                 'seasonality_fourier_oder' : [[5, 10], [10,15], [15, 20]]}

# grid = ParameterGrid(params_grid)
# cnt = 0
# for parameters in grid:
#     cnt = cnt+1

# print('Total Possible Models',cnt)

# %%
from fractions import Fraction

# %%
params_grid = {
'seasonality_fourier_order' : [[5, 10], [10,15], [15, 20]],
'seasonality_periods' : [[1/12, 1/8], [1/12, 1/6], [1/12, 1/4], [1/24, 1/16], [1/24, 1/12], [1/24, 1/8]]
}

grid = ParameterGrid(params_grid)
cnt = 0
for parameters in grid:
    cnt = cnt+1

print('Total Possible Models',cnt)
# Out:
# Total Possible Models 18

# %% [markdown]
# ### grid_search

# %%
def train(x_series, y_series, **paras):
    
    x_df = prophet_preprocessor(x_series)
    
    model = NeuralProphet(
                        #   n_changepoints = paras['n_changepoints'],
                        #   changepoints_range = paras['changepoints_range'],
                        #   num_hidden_layers = paras['num_hidden_layers'],
                         
                          learning_rate = 0.01,
                        #   trend_reg = 0.05, seasonality_reg = 0.1,
                          yearly_seasonality = False, weekly_seasonality = False, daily_seasonality = False,
                          epochs= 50, batch_size = 64
                         )
    
    model.add_seasonality(name='first_seasonality', period=paras['seasonality_periods'][0], fourier_order=paras['seasonality_fourier_order'][0]) 
    model.add_seasonality(name='second_seasonality', period=paras['seasonality_periods'][1], fourier_order=paras['seasonality_fourier_order'][1])

    metrics = model.fit(x_df, freq="min")

    future = model.make_future_dataframe(x_df, periods=120)
    forecast = model.predict(future)
    error = mean_squared_error(y_series, forecast.yhat1.values[-120:])

    return error

# %%
def experiment(train_x_array, train_y_array, args):
    
    sample_indices = coin_index_export(input_array = train_x_array, coin_num= args.coin_num)
    args.sample_id_indices = random.sample(sample_indices, 5)
    print(args.sample_id_indices)

    
    result = pd.DataFrame(columns = ['MSE*10E5', 'PARAMETERS'])

    for paras in grid:
        print("")
        print(f'\n current parameters is {paras}\n')
        total_mse = 0.0

        for sample_id in args.sample_id_indices:

            x_series = train_x_array[sample_id, :, args.data_col_idx] 
            y_series = train_y_array[sample_id, :, args.data_col_idx]

            temp_mse = train(x_series, y_series, **paras)
            total_mse += temp_mse * 10E5
            
        print('\nTotal MSE Error------------------------------------', total_mse, end='\n')
        result = result.append({'MSE*10E5':total_mse, 'PARAMETERS':paras},ignore_index=True)


    return result

# %%
train_x_array = df2d_to_array3d(train_x_df)
train_y_array = df2d_to_array3d(train_y_df)

seed = 7

np.random.seed(seed)
set_random_seed(seed)
random.seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")

args.data_col_idx = 1 # 1 open, 2 high
args.coin_num = 9

# %%
result = experiment(train_x_array, train_y_array, deepcopy(args))
# Out:
# 0/50]: 100%|██████████| 50/50 [00:02<00:00, 16.99it/s, SmoothL1Loss=0.0178, MAE=0.00189, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 16.56it/s, SmoothL1Loss=0.0232, MAE=0.00713, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:02<00:00, 16.99it/s, SmoothL1Loss=0.00871, MAE=0.00535, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[3/50]:   4%|▍         | 2/50 [00:00<00:03, 15.91it/s, SmoothL1Loss=1.05, MAE=0.017, RegLoss=0]
# Total MSE Error------------------------------------ 279.1283688657371
#
#
#  current parameters is {'seasonality_fourier_order': [5, 10], 'seasonality_periods': [0.08333333333333333, 0.25]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 16.43it/s, SmoothL1Loss=0.00828, MAE=0.00115, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:02<00:00, 17.12it/s, SmoothL1Loss=0.0102, MAE=0.00725, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:02<00:00, 16.86it/s, SmoothL1Loss=0.0304, MAE=0.00257, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:04<00:00, 12.08it/s, SmoothL1Loss=0.00375, MAE=0.00288, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.81it/s, SmoothL1Loss=0.00278, MAE=0.00303, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   0%|          | 0/50 [00:00<?, ?it/s]
# Total MSE Error------------------------------------ 341.835927531342
#
#
#  current parameters is {'seasonality_fourier_order': [5, 10], 'seasonality_periods': [0.041666666666666664, 0.0625]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  9.72it/s, SmoothL1Loss=0.0107, MAE=0.00132, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:04<00:00, 10.28it/s, SmoothL1Loss=0.00752, MAE=0.00641, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:04<00:00, 12.01it/s, SmoothL1Loss=0.0189, MAE=0.00196, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 13.11it/s, SmoothL1Loss=0.00571, MAE=0.00346, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:04<00:00, 11.46it/s, SmoothL1Loss=0.00692, MAE=0.0047, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[2/50]:   4%|▍         | 2/50 [00:00<00:03, 15.08it/s, SmoothL1Loss=0.638, MAE=0.0117, RegLoss=0]
# Total MSE Error------------------------------------ 227.849852397603
#
#
#  current parameters is {'seasonality_fourier_order': [5, 10], 'seasonality_periods': [0.041666666666666664, 0.08333333333333333]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:04<00:00, 11.23it/s, SmoothL1Loss=0.0127, MAE=0.00146, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  9.27it/s, SmoothL1Loss=0.00588, MAE=0.00594, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.70it/s, SmoothL1Loss=0.014, MAE=0.00167, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.11it/s, SmoothL1Loss=0.0041, MAE=0.00298, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.40it/s, SmoothL1Loss=0.00784, MAE=0.00484, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   2%|▏         | 1/50 [00:00<00:05,  9.20it/s, SmoothL1Loss=0.722, MAE=0.0131, RegLoss=0]
# Total MSE Error------------------------------------ 251.45575741560134
#
#
#  current parameters is {'seasonality_fourier_order': [5, 10], 'seasonality_periods': [0.041666666666666664, 0.125]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.73it/s, SmoothL1Loss=0.00994, MAE=0.00126, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.86it/s, SmoothL1Loss=0.0122, MAE=0.00906, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.99it/s, SmoothL1Loss=0.0178, MAE=0.002, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:09<00:00,  5.36it/s, SmoothL1Loss=0.0072, MAE=0.00391, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:07<00:00,  6.42it/s, SmoothL1Loss=0.0117, MAE=0.00632, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   0%|          | 0/50 [00:00<?, ?it/s]
# Total MSE Error------------------------------------ 412.6104990643145
#
#
#  current parameters is {'seasonality_fourier_order': [10, 15], 'seasonality_periods': [0.08333333333333333, 0.125]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.26it/s, SmoothL1Loss=0.0212, MAE=0.00187, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.61it/s, SmoothL1Loss=0.00974, MAE=0.00723, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.93it/s, SmoothL1Loss=0.0127, MAE=0.00164, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.82it/s, SmoothL1Loss=0.00545, MAE=0.0033, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.55it/s, SmoothL1Loss=0.0065, MAE=0.00446, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   2%|▏         | 1/50 [00:00<00:05,  8.50it/s, SmoothL1Loss=1.02, MAE=0.0168, RegLoss=0]
# Total MSE Error------------------------------------ 215.12213976881986
#
#
#  current parameters is {'seasonality_fourier_order': [10, 15], 'seasonality_periods': [0.08333333333333333, 0.16666666666666666]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.60it/s, SmoothL1Loss=0.011, MAE=0.00138, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.87it/s, SmoothL1Loss=0.00566, MAE=0.0056, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.39it/s, SmoothL1Loss=0.0189, MAE=0.00197, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.18it/s, SmoothL1Loss=0.00376, MAE=0.00275, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.29it/s, SmoothL1Loss=0.00343, MAE=0.00322, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   0%|          | 0/50 [00:00<?, ?it/s]
# Total MSE Error------------------------------------ 356.512084178403
#
#
#  current parameters is {'seasonality_fourier_order': [10, 15], 'seasonality_periods': [0.08333333333333333, 0.25]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:07<00:00,  6.56it/s, SmoothL1Loss=0.00973, MAE=0.00128, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.64it/s, SmoothL1Loss=0.00959, MAE=0.00723, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.28it/s, SmoothL1Loss=0.0147, MAE=0.00178, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.94it/s, SmoothL1Loss=0.00349, MAE=0.0028, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.56it/s, SmoothL1Loss=0.00274, MAE=0.00301, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   2%|▏         | 1/50 [00:00<00:06,  7.62it/s, SmoothL1Loss=1.58, MAE=0.0238, RegLoss=0]
# Total MSE Error------------------------------------ 294.6670981712233
#
#
#  current parameters is {'seasonality_fourier_order': [10, 15], 'seasonality_periods': [0.041666666666666664, 0.0625]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.95it/s, SmoothL1Loss=0.0138, MAE=0.00146, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:07<00:00,  6.77it/s, SmoothL1Loss=0.00567, MAE=0.00583, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:07<00:00,  6.94it/s, SmoothL1Loss=0.02, MAE=0.00207, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.62it/s, SmoothL1Loss=0.00909, MAE=0.0043, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.05it/s, SmoothL1Loss=0.00528, MAE=0.00413, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
#   0%|          | 0/50 [00:00<?, ?it/s]
# Total MSE Error------------------------------------ 257.16360979079315
#
#
#  current parameters is {'seasonality_fourier_order': [10, 15], 'seasonality_periods': [0.041666666666666664, 0.08333333333333333]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.64it/s, SmoothL1Loss=0.0127, MAE=0.00141, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.63it/s, SmoothL1Loss=0.00552, MAE=0.00581, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.69it/s, SmoothL1Loss=0.0168, MAE=0.00177, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.11it/s, SmoothL1Loss=0.00567, MAE=0.00333, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.60it/s, SmoothL1Loss=0.00498, MAE=0.00397, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   0%|          | 0/50 [00:00<?, ?it/s, SmoothL1Loss=1.95, MAE=0.0282, RegLoss=0]
# Total MSE Error------------------------------------ 308.305544415196
#
#
#  current parameters is {'seasonality_fourier_order': [10, 15], 'seasonality_periods': [0.041666666666666664, 0.125]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:07<00:00,  7.07it/s, SmoothL1Loss=0.0286, MAE=0.00222, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.13it/s, SmoothL1Loss=0.0123, MAE=0.00905, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.15it/s, SmoothL1Loss=0.0201, MAE=0.00211, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:07<00:00,  6.84it/s, SmoothL1Loss=0.0363, MAE=0.00873, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.50it/s, SmoothL1Loss=0.00408, MAE=0.00383, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   0%|          | 0/50 [00:00<?, ?it/s]
# Total MSE Error------------------------------------ 559.1586141503241
#
#
#  current parameters is {'seasonality_fourier_order': [15, 20], 'seasonality_periods': [0.08333333333333333, 0.125]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.46it/s, SmoothL1Loss=0.0123, MAE=0.00141, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.82it/s, SmoothL1Loss=0.0108, MAE=0.0075, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  8.26it/s, SmoothL1Loss=0.0228, MAE=0.00227, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.68it/s, SmoothL1Loss=0.00612, MAE=0.00362, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.43it/s, SmoothL1Loss=0.00375, MAE=0.00352, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   0%|          | 0/50 [00:00<?, ?it/s]
# Total MSE Error------------------------------------ 194.08496266427971
#
#
#  current parameters is {'seasonality_fourier_order': [15, 20], 'seasonality_periods': [0.08333333333333333, 0.16666666666666666]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.47it/s, SmoothL1Loss=0.0312, MAE=0.00242, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.62it/s, SmoothL1Loss=0.00529, MAE=0.00547, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:05<00:00,  8.76it/s, SmoothL1Loss=0.0165, MAE=0.00186, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:06<00:00,  7.63it/s, SmoothL1Loss=0.00935, MAE=0.00437, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:04<00:00, 11.23it/s, SmoothL1Loss=0.0056, MAE=0.00415, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[2/50]:   0%|          | 0/50 [00:00<?, ?it/s, SmoothL1Loss=0.637, MAE=0.012, RegLoss=0]
# Total MSE Error------------------------------------ 363.6101268394758
#
#
#  current parameters is {'seasonality_fourier_order': [15, 20], 'seasonality_periods': [0.08333333333333333, 0.25]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 13.14it/s, SmoothL1Loss=0.00591, MAE=0.000969, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 13.45it/s, SmoothL1Loss=0.0216, MAE=0.0116, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 15.12it/s, SmoothL1Loss=0.0234, MAE=0.00227, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.91it/s, SmoothL1Loss=0.009, MAE=0.00448, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 15.28it/s, SmoothL1Loss=0.00203, MAE=0.00258, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[2/50]:   0%|          | 0/50 [00:00<?, ?it/s, SmoothL1Loss=1.02, MAE=0.0169, RegLoss=0]
# Total MSE Error------------------------------------ 245.62708182918033
#
#
#  current parameters is {'seasonality_fourier_order': [15, 20], 'seasonality_periods': [0.041666666666666664, 0.0625]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 15.17it/s, SmoothL1Loss=0.0128, MAE=0.00148, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 15.31it/s, SmoothL1Loss=0.0053, MAE=0.00563, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 15.20it/s, SmoothL1Loss=0.0401, MAE=0.00275, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 15.59it/s, SmoothL1Loss=0.00807, MAE=0.004, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.91it/s, SmoothL1Loss=0.0035, MAE=0.00343, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[2/50]:   4%|▍         | 2/50 [00:00<00:03, 15.08it/s, SmoothL1Loss=0.663, MAE=0.0123, RegLoss=0]
# Total MSE Error------------------------------------ 201.57308600644217
#
#
#  current parameters is {'seasonality_fourier_order': [15, 20], 'seasonality_periods': [0.041666666666666664, 0.08333333333333333]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 15.63it/s, SmoothL1Loss=0.0113, MAE=0.00136, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 13.16it/s, SmoothL1Loss=0.00874, MAE=0.0067, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 13.81it/s, SmoothL1Loss=0.017, MAE=0.0019, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.11it/s, SmoothL1Loss=0.00416, MAE=0.00284, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.44it/s, SmoothL1Loss=0.00385, MAE=0.00368, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[1/50]:   0%|          | 0/50 [00:00<?, ?it/s, SmoothL1Loss=0.887, MAE=0.0152, RegLoss=0]
# Total MSE Error------------------------------------ 227.05477805828895
#
#
#  current parameters is {'seasonality_fourier_order': [15, 20], 'seasonality_periods': [0.041666666666666664, 0.125]}
#
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.21it/s, SmoothL1Loss=0.0109, MAE=0.00132, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.87it/s, SmoothL1Loss=0.00893, MAE=0.00722, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.53it/s, SmoothL1Loss=0.0207, MAE=0.00217, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.38it/s, SmoothL1Loss=0.00821, MAE=0.00423, RegLoss=0]
# WARNING: nprophet - fit: Parts of code may break if using other than daily data.
# Epoch[50/50]: 100%|██████████| 50/50 [00:03<00:00, 14.21it/s, SmoothL1Loss=0.00319, MAE=0.00326, RegLoss=0]
# Total MSE Error------------------------------------ 296.2146887344497

# %%
result = result.sort_values(by =['MSE*10E5'])
result = result.reset_index(drop=True)

# %%
result
# Out:
#       MSE*10E5                                         PARAMETERS
# 0   181.676408  {'seasonality_fourier_order': [5, 10], 'season...
# 1   194.084963  {'seasonality_fourier_order': [15, 20], 'seaso...
# 2   201.573086  {'seasonality_fourier_order': [15, 20], 'seaso...
# 3   215.122140  {'seasonality_fourier_order': [10, 15], 'seaso...
# 4   227.054778  {'seasonality_fourier_order': [15, 20], 'seaso...
# 5   227.849852  {'seasonality_fourier_order': [5, 10], 'season...
# 6   245.627082  {'seasonality_fourier_order': [15, 20], 'seaso...
# 7   251.455757  {'seasonality_fourier_order': [5, 10], 'season...
# 8   257.163610  {'seasonality_fourier_order': [10, 15], 'seaso...
# 9   279.128369  {'seasonality_fourier_order': [5, 10], 'season...
# 10  294.667098  {'seasonality_fourier_order': [10, 15], 'seaso...
# 11  296.214689  {'seasonality_fourier_order': [15, 20], 'seaso...
# 12  308.305544  {'seasonality_fourier_order': [10, 15], 'seaso...
# 13  341.835928  {'seasonality_fourier_order': [5, 10], 'season...
# 14  356.512084  {'seasonality_fourier_order': [10, 15], 'seaso...
# 15  363.610127  {'seasonality_fourier_order': [15, 20], 'seaso...
# 16  412.610499  {'seasonality_fourier_order': [5, 10], 'season...
# 17  559.158614  {'seasonality_fourier_order': [10, 15], 'seaso...

# %%
result.to_csv('add_seasonality_grid_search.csv')

# %%
result['PARAMETERS'][0]
# Out:
# {'seasonality_fourier_order': [5, 10],
#  'seasonality_periods': [0.08333333333333333, 0.125]}

# %%
1/12, 1/8
# Out:
# (0.08333333333333333, 0.125)

# %%
# plt.plot(np.arange(1380, 1380+120), y_series, label = 'True series')
# plt.plot(np.arange(1380, 1380+120), forecast.yhat1.values[-120:], label = 'Neural Prophet1')
# plt.legend()
# plt.show()

# error = mean_squared_error(y_series, forecast.yhat1.values[-120:])
# print("Prophet MSE*10E5 is {}".format(error * 10E5))
